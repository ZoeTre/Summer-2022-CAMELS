# %%
#need to fix how params are being replaced
#options: save to new text file, use dictionary, make a list
#feed in param from LHC txt file in first loop

# %%
tst_str =  """#main free parameters
#chi_gas
1.7 
#sigma_crit
6.0
#tau_star_0
1.0
#recipe for quiescent star formation 0=kenn density 1=bigiel1 2=bigiel2
2
#H2 recipe (0 = GK 1 = KMT 2= BR)
0
#ionized gas
#sigma_HII 
0.4 
#fion_internal
0.2
#epsilon_SN_0 
1.7 
#alpha_rh 
3.0 
#f_eject_thresh (km/s)
110.0
#gas is ejected if V_halo<f_eject_thresh
#drive_AGN_winds 
1 
#epsilon_wind_QSO
0.50000
#YIELD 
1.2 
#f_enrich_cold
1.0
#cooling enrichment (0=self-consistent 1=fixed) 
0
#Zh_fixed
0.0
#radio heating parameters: f_Edd_radio
0.002
#f_recycle (recycled gas from mass loss/SN)
0.43
#BH parameters
0.5
#fbhcrit 
0.4
#tau_Q 
0.04 
#mseedbh
1.0E04
#bhmassbulgemassev
1
#0=NOEV 1= ZEV 2=FGAS 3=BHFP
#sigmaBH_create
0.3
#tidal stripping (0/1)
1
#if on, expects arguments:
#f_strip 
1.0
#tau_strip 
0.22
#f_dis
0.8
#to make stripping MORE effective make f_strip<1
#to make stripping less effective make f_strip>1
#f_scatter
0.2
#f_return (re-infall of ejected gas)
0.1
#SQUELCH 
1
#z1 
9.0
#z2 
3.5
#z_squelch
8.0
#z1 and z2 should be regarded as just parameters in the okamoto fitting fnc
#z_squelch is the redshift that squelching is turned on
#disk model 0=SP 1=isothermal 2=MMW
2
#alpha_burst
3.0
#disk instability
1
#0=off 1=on (stars+gas)
#epsilon_m
0.3
#cosmological parameters
#geometry: 0=EDS, 1=FLAT, 2=OPEN
1
#Omega_0 (matter) 
0.25100
#Omega_Lambda_0 
0.74900
#h_100
0.6711
#f_baryon: negative number means use default value
0.1952"""

# %%
print(tst_str)
# Out:
# #main free parameters
# #chi_gas
# 1.7
# #sigma_crit
# 6.0
# #tau_star_0
# 1.0
# #recipe for quiescent star formation 0=kenn density 1=bigiel1 2=bigiel2
# 2
# #H2 recipe (0 = GK 1 = KMT 2= BR)
# 0
# #ionized gas
# #sigma_HII
# 0.4
# #fion_internal
# 0.2
# #epsilon_SN_0
# 1.7
# #alpha_rh
# 3.0
# #f_eject_thresh (km/s)
# 110.0
# #gas is ejected if V_halo<f_eject_thresh
# #drive_AGN_winds
# 1
# #epsilon_wind_QSO
# 0.50000
# #YIELD
# 1.2
# #f_enrich_cold
# 1.0
# #cooling enrichment (0=self-consistent 1=fixed)
# 0
# #Zh_fixed
# 0.0
# #radio heating parameters: f_Edd_radio
# 0.002
# #f_recycle (recycled gas from mass loss/SN)
# 0.43
# #BH parameters
# 0.5
# #fbhcrit
# 0.4
# #tau_Q
# 0.04
# #mseedbh
# 1.0E04
# #bhmassbulgemassev
# 1
# #0=NOEV 1= ZEV 2=FGAS 3=BHFP
# #sigmaBH_create
# 0.3
# #tidal stripping (0/1)
# 1
# #if on, expects arguments:
# #f_strip
# 1.0
# #tau_strip
# 0.22
# #f_dis
# 0.8
# #to make stripping MORE effective make f_strip<1
# ...

# %%
params = [
    
"chi_gas",

"sigma_crit",

"tau_star_0",

"quiescent star formation",

"H2 recipe",

"sigma_HII",

"fion_internal",

"epsilon_SN_0",

"alpha_rh",

"f_eject_thresh",

"drive_AGN_winds",

"epsilon_wind_QSO",

"YIELD",

"f_enrich_cold",

"cooling enrichment",

"Zh_fixed",

"f_Edd_radio",

"f_recycle",

"BH parameters",

"fbhcrit",

"tau_Q",

"mseedbh",

"bhmassbulgemassev",

"sigmaBH_create",

"tidal stripping",

"f_strip",

"tau_strip",

"f_dis",

"f_scatter",

"f_return",

"SQUELCH",

"z1",

"z2",

"z_squelch",


"disk model",

"alpha_burst",

"disk instability",

"epsilon_m",

"geometry",

"Omega_0",

"Omega_Lambda_0",

"h_100",

"f_baryon"
 

    ]

# %%
txt_to_read = open('LHC_test.txt', 'r')

# %%
first_line = (txt_to_read.readline())

# %%
print((first_line))
# Out:
# M,S, Asn2, Asn1, Aagn,

# %%
# chosen_params = [str(i) for i in first_line.rsplit(",") if i!= ' \n']

# %%
# print(chosen_params)

params_fake = ['epsilon_m', 'f_scatter', 'tau_Q', 'alpha_rh', "alpha_burst"]

# %%
#alternatively: could use dictionary

#for ex: for p, value in params_fake.iteritems()

#could help avoid format/ order issues

# %%
positions_list = []

for position, para in enumerate(params):
    
    for p in params_fake:
    
        if para == p:
            
            print(position)
            
            positions_list.append(position)
# Out:
# 8
# 20
# 28
# 35
# 37

# %%
print((positions_list))
# Out:
# [8, 20, 28, 35, 37]

# %%
#i have a string w/ comments and parameter values

#i can skip comments to print just param values

#i also have a list of parameters, and thus their positions

#i could separate each value so that each one has it's own line

#then there should be as many non-comment lines as there are parameters

#replace the line with %s 

# count = 0

# for i in tst_str.rsplit("\n"):
    

#     if i.startswith('#'):

#         pass
#     else:

#         count+=1
            
        
#         if count in positions_list:
            
#             tst_str = tst_str.replace(i, "%s", 1)
            
#             print(i)

# %%
# count = 0

# for i in tst_str.rsplit("\n"):
    

#     if i.startswith('#'):

#         pass
#     else:
        
        
#         print(i)
        
#         print(count)
        
#         if count in positions_list:
            
#             print('YES')
            
#             tst_str = tst_str.replace(i, "%s", 1) #can i directly replace/append value from LHC txt file?
        
#         print('-------------')
        
#         count+=1

# %%
u_s = open("save_unformatted_string.txt", 'x')

u_s = open("save_unformatted_string.txt", 'w')

# %%
# test_list = []

# for i in tst_str.rsplit("\n"):
    
#     if i.startswith('#'):

#         pass
    
#     else:
    
#         test_list.append(str(i))
#     #test_list.append('\n')
    
    
# for index, value in enumerate(test_list):
    
#     u_s.write(value)
    
    
#     for param in nw_st.rsplit(', '):
    
#     #print(index)

#         if index in positions_list:
            
#             u_s.write(param)
            
            
            
#             #test_list[index] = param
            
#             #test_list = list(map(lambda x: x.replace(value, param), test_list))
            
           
#             #print(flex)

            
#             #print(value)
            
            
# u_s.close()

# %%
# test_list = []

# for i in tst_str.rsplit("\n"):
    
#     if i.startswith('#'):

#         pass
    
#     else:
    
#         test_list.append(str(i))
#     #test_list.append('\n')
    
# unformatted_string = []  

# for index, value in enumerate(test_list):
    
#     unformatted_string.append(value)
    
    
#     for param in nw_st.rsplit(', '):
    
#     #print(index)

#         if index in positions_list:
            
#             unformatted_string.append(param)
            
            
            
#             #test_list[index] = param
            
#             #test_list = list(map(lambda x: x.replace(value, param), test_list))
            
           
#             #print(flex)

            
#             #print(value)

# %%
test_list = []

for i in tst_str.rsplit("\n"):
    
    if i.startswith('#'):

        pass
    
    else:
    
        test_list.append(str(i))
    #test_list.append('\n')
    
# unformatted_string = []  

for index, value in enumerate(test_list):
    
#     unformatted_string.append(value)
    
    for param in nw_st.rsplit(', '):
    
#     #print(index)

        if index in positions_list:
            
#             unformatted_string.append(param)
            
            
            
        #test_list[index] = param
            
            test_list = list(map(lambda x: x.replace(value, param), test_list))
            
           
#             #print(flex)

            
#             #print(value)

# %%
x_st= '0.426392395832758, 0.9103636065857955, -1.2949352952923796, 1.2570805772020746, 3.1785480935541024'

# %%
# x_stl = x_st.rsplit(', ')

# for index, value in enumerate(test_list):
    
#     #for param in x_stl:
        
#     for ind, param in enumerate(x_stl):
        
        
#         if index in positions_list:
            
            
#             test_list = list(map(lambda x: x.replace(value, param), test_list))
#             #test_list = list(map(lambda x: x.replace(value, param, test_list)))
            
#             #print(x_stl[ind+nex])
#            # x_stl.remove(param)
    
            
# #             x_stl.pop(0)

    
            
# #             print(x_stl)

# %%
test_list = []

for i in tst_str.rsplit("\n"):
    
    if i.startswith('#'):

        pass
    
    else:
    
        test_list.append(str(i))

x_stl = x_st.rsplit(', ')

for index, value in enumerate(test_list):  

    #for param in nw_st.rsplit(', '):
        
    if index in positions_list:
            
        #test_list = list(map(lambda x: x.replace(value, x_stl[0]), test_list))
        
        test_list[index] = x_stl[0]
        
        x_stl.pop(0)
        
        #print(x_stl[0])

# %%
# for ind, param in enumerate(x_stl):
    
    
    
#     print(x_stl[ind+1])

# %%
new_vals_string = ''

for val in test_list:
    
    new_vals_string+= val
    
    new_vals_string+= ', '
    
new_vals_string = new_vals_string[:-2]
    
print(new_vals_string)
# Out:
# 1.7 , 6.0, 1.0, 2, 0, 0.4 , 0.2, 1.7 , 0.426392395832758, 110.0, 1 , 0.50000, 1.2 , 1.0, 0, 0.0, 0.002, 0.43, 0.5, 0.4, 0.9103636065857955, 1.0E04, 1, 0.3, 1, 1.0, 0.22, 0.8, -1.2949352952923796, 0.1, 1, 9.0, 3.5, 8.0, 2, 1.2570805772020746, 1, 3.1785480935541024, 1, 0.25100, 0.74900, 0.6711, 0.1952

# %%
#but now instead of replacing with %s, replace with actual value from txt file

# %%
#create new txt file

#keep adding all stuff to it

#once count == value in positions list

#add in new %s character instead of what's already there

# %%
for i in tst_str.rsplit("\n"):
    

    if i.startswith('#'):

        pass
    else:
        
        
        print(i)
# Out:
# 1.7
# 6.0
# 1.0
# 2
# 0
# 0.4
# %s
# 1.7
# %s
# 110.0
# 1
# 0.50000
# 1.2
# 1.0
# 0
# 0.0
# 0.002
# 0.43
# 0.5
# 0.4
# %s
# 1.0E04
# 1
# %s
# 1
# 1.0
# 0.22
# 0.8
# 0.2
# 0.1
# 1
# 9.0
# 3.5
# 8.0
# 2
# %s
# 1
# 0.3
# 1
# 0.25100
# 0.74900
# 0.6711
# 0.1952

# %% [markdown]
# # Replacing by number instead of index? meaning: it needs to replace 1.3, sees 1.7 with 1 in front and replaces that first?

# %%
print(tst_str)
# Out:
# #main free parameters
# #chi_gas
# 1.7
# #sigma_crit
# 6.0
# #tau_star_0
# 1.0
# #recipe for quiescent star formation 0=kenn density 1=bigiel1 2=bigiel2
# 2
# #H2 recipe (0 = GK 1 = KMT 2= BR)
# 0
# #ionized gas
# #sigma_HII
# 0.4
# #fion_internal
# %s
# #epsilon_SN_0
# 1.7
# #alpha_rh
# %s
# #f_eject_thresh (km/s)
# 110.0
# #gas is ejected if V_halo<f_eject_thresh
# #drive_AGN_winds
# 1
# #epsilon_wind_QSO
# 0.50000
# #YIELD
# 1.2
# #f_enrich_cold
# 1.0
# #cooling enrichment (0=self-consistent 1=fixed)
# 0
# #Zh_fixed
# 0.0
# #radio heating parameters: f_Edd_radio
# 0.002
# #f_recycle (recycled gas from mass loss/SN)
# 0.43
# #BH parameters
# 0.5
# #fbhcrit
# 0.4
# #tau_Q
# %s
# #mseedbh
# 1.0E04
# #bhmassbulgemassev
# 1
# #0=NOEV 1= ZEV 2=FGAS 3=BHFP
# #sigmaBH_create
# %s
# #tidal stripping (0/1)
# 1
# #if on, expects arguments:
# #f_strip
# 1.0
# #tau_strip
# 0.22
# #f_dis
# 0.8
# #to make stripping MORE effective make f_strip<1
# #to make stripping less effective make f_strip>1
# ...

# %%
print(txt_to_read.read())
# Out:
# 0.426392395832758, 0.9103636065857955, -1.2949352952923796, 1.2570805772020746, 3.1785480935541024, 0.47167853199636256, 0.8191504519999148, -0.9372311832492476, 3.7477206620474224, 1.4328400491294657, 0.12400941750136327, 0.6251591327383723, 1.2514334727147847, 3.1815841094358968, 0.4827551409241993, 0.3223433839816943, 0.7065701320697265, 0.20929427762986275, 2.0688161038016584, 2.537452511710981, 0.29213876066600236, 0.6712646385048495, -0.7711693672197689, 3.3210750775399283, 2.0678240496456763, 0.22340852154358692, 0.8404117986514773, 1.1129435366260738, 2.332794126201172, 2.341398285102133, 0.34286657142782745, 0.971440979362093, -0.08364030257072971, 1.4257278065020418, 3.315349337266281, 0.170737722708119, 0.7235432015361439, -1.759252180815515, 0.9126755026609172, 0.9176277571185345, 0.20621460514465184, 0.9245075761526478, 0.419168323308401, 2.5200182306691583, 1.2796221450045717, 0.4124645968140458, 0.7897830173911886, 1.716807280408713, 0.4693063077457666, 3.7384706040528
# ...

# %%
#go through line by line, 

#feed line to string

#save string as its own text file ** except actually i want to format and then save as a text file


# count = 1

# day = "%s is %s"

# rep = ('tomorrow', 'thursday')

# print(day % rep)

# %%
#modify this:

#one line from LHC text file at a time

# %%
txt_to_read = open('LHC_test.txt', 'r')

st =''


#count = 0

for line in txt_to_read:
    
    st += line
        
    #count +=1
        
#     if count == len(positions_list):
        
#         st+= '\n'
    
    
#for line in 
    
    
#         replace_params = []

#         replace_params.append(line)

#         replace_params = tuple(replace_params)

#         print(replace_params)

#     pf= open("param_file_unformatted.txt", "x")
    
#     pf.write(tst_str % replace_params)
    
    
    #print(line)
    
 #need to split this

# %%
'\n' in st
# Out:
# True

# %%
#pf= open("param_file_unformatted.txt", "x")

# %%
for line in st.rsplit("\n"):

    nw_st = (st.rsplit("\n")[1])
        
print(nw_st)
        
        
        
# for line in nw_st.rsplit("\n"):
    
#     print(line)
        
    
#         replace_params = line.rsplit(",")

#         replace_params = str(replace_params)
        

#         replace_params = tuple(replace_params)

#         #pf= open("param_file_unformatted.txt", "w")

#         #pf.write(replace_params)
    
# #     for i in replace_params:
        
# #         print(type(i))

#         string_unformatted = tst_str % replace_params
    
#         print(string_unformatted)
    
    
#         pf= open("param_file_unformatted.txt", "w")

#         pf.write(string_unformatted)
    
    
#     #print(replace_params)
    
    
    
         
# #     pf= open("param_file_unformatted.txt", "w")
        
# #     pf.write(tst_str % replace_params)
# Out:
# 0.426392395832758, 0.9103636065857955, -1.2949352952923796, 1.2570805772020746, 3.1785480935541024, 0.47167853199636256, 0.8191504519999148, -0.9372311832492476, 3.7477206620474224, 1.4328400491294657, 0.12400941750136327, 0.6251591327383723, 1.2514334727147847, 3.1815841094358968, 0.4827551409241993, 0.3223433839816943, 0.7065701320697265, 0.20929427762986275, 2.0688161038016584, 2.537452511710981, 0.29213876066600236, 0.6712646385048495, -0.7711693672197689, 3.3210750775399283, 2.0678240496456763, 0.22340852154358692, 0.8404117986514773, 1.1129435366260738, 2.332794126201172, 2.341398285102133, 0.34286657142782745, 0.971440979362093, -0.08364030257072971, 1.4257278065020418, 3.315349337266281, 0.170737722708119, 0.7235432015361439, -1.759252180815515, 0.9126755026609172, 0.9176277571185345, 0.20621460514465184, 0.9245075761526478, 0.419168323308401, 2.5200182306691583, 1.2796221450045717, 0.4124645968140458, 0.7897830173911886, 1.716807280408713, 0.4693063077457666, 3.7384706040528
# ...

# %%
for param in nw_st.rsplit(', '):
    
    print(param)
# Out:
# 0.426392395832758
# 0.9103636065857955
# -1.2949352952923796
# 1.2570805772020746
# 3.1785480935541024
# 0.47167853199636256
# 0.8191504519999148
# -0.9372311832492476
# 3.7477206620474224
# 1.4328400491294657
# 0.12400941750136327
# 0.6251591327383723
# 1.2514334727147847
# 3.1815841094358968
# 0.4827551409241993
# 0.3223433839816943
# 0.7065701320697265
# 0.20929427762986275
# 2.0688161038016584
# 2.537452511710981
# 0.29213876066600236
# 0.6712646385048495
# -0.7711693672197689
# 3.3210750775399283
# 2.0678240496456763
# 0.22340852154358692
# 0.8404117986514773
# 1.1129435366260738
# 2.332794126201172
# 2.341398285102133
# 0.34286657142782745
# 0.971440979362093
# -0.08364030257072971
# 1.4257278065020418
# 3.315349337266281
# 0.170737722708119
# 0.7235432015361439
# -1.759252180815515
# 0.9126755026609172
# 0.9176277571185345
# 0.20621460514465184
# 0.9245075761526478
# 0.419168323308401
# 2.5200182306691583
# 1.2796221450045717
# 0.4124645968140458
# 0.7897830173911886
# ...

# %%
# ttry  = ['hamster', 'elderberries', 'corn']

# %%
# enter_to = 'your mother was a %s and your father smells of %s'

# %%
# ttry = tuple(ttry)

# %%
# print(enter_to % ttry)

# %%
#so its a length issue 

#i want to feed a single line of the txt file to the string

#save that 

#then move on to the next line



# count=0
    
# for line in st:
    
#     count+=1
    
#     if line=='\n':
        
#         print(line)
        
#     else:
        
#         print('no')
        
        
        #break

# %%
nw_st.count('\n')

# %%
# ount = 0

# index = -1

# for i in nw_st:
    
#     index+=1
    
#     if i == ',':
        
#         ount+=1
        
#         if ount%len(positions_list)==0:
            
#             nw_st = nw_st[:index] + '\n' + nw_st[index:]

# %%
#print(nw_st)

# %%
# track = 0

# for line in nw_st.rsplit('\n'):
    
#     track+=1
    
#     replace_ps = ''
    
#     replace_ps+=line
    
    
#     if track ==1:
        
#         break
        
        
# replace_ps = replace_ps.rsplit(', ')
    
# replace_ps = tuple(replace_ps)   
        
        
# print(replace_ps)

# %%
#print(tst_str % replace_ps)

# %%
commas = 0

index = 0

for i in nw_st:
    
    index+=1
    
    if i == ',':
        
        commas+=1
        
        #if commas == len(positions_list):
        if commas == len(positions_list):
            
            nw_st = nw_st[:index] + '\n'+ nw_st[index:]
            
            commas = 0
        
        #if ount%len(positions_list)==0:
        #if commas%5==0:
        
            
#             print(commas)
            
#             nw_st = nw_st[:index] + '\n' + nw_st[index:]




# for i in nw_st:
    
#     if i == ',':
        
#         commas+=1
        
#         if commas ==len(positions_list):
            
#             nw_str = (nw_st[:index] + '\n' + nw_st[index:])
           
#             commas = 0

# %%
print(nw_st)
# Out:
# 0.426392395832758, 0.9103636065857955, -1.2949352952923796, 1.2570805772020746, 3.1785480935541024,
#  0.47167853199636256, 0.8191504519999148, -0.9372311832492476, 3.7477206620474224, 1.4328400491294657
# , 0.12400941750136327, 0.6251591327383723, 1.2514334727147847, 3.1815841094358968, 0.482755140924199
# 3, 0.3223433839816943, 0.7065701320697265, 0.20929427762986275, 2.0688161038016584, 2.5374525117109
# 81, 0.29213876066600236, 0.6712646385048495, -0.7711693672197689, 3.3210750775399283, 2.0678240496456
# 763, 0.22340852154358692, 0.8404117986514773, 1.1129435366260738, 2.332794126201172, 2.34139828510
# 2133, 0.34286657142782745, 0.971440979362093, -0.08364030257072971, 1.4257278065020418, 3.3153493372
# 66281, 0.170737722708119, 0.7235432015361439, -1.759252180815515, 0.9126755026609172, 0.9176277571
# 185345, 0.20621460514465184, 0.9245075761526478, 0.419168323308401, 2.5200182306691583, 1.279622145
# ...

# %%
      
# for line in nw_st.rsplit("\n"):
    
#     print(line)
        
    
#         replace_params = line.rsplit(",")

#         replace_params = str(replace_params)
        

#         replace_params = tuple(replace_params)

#         #pf= open("param_file_unformatted.txt", "w")

#         #pf.write(replace_params)
    
# #     for i in replace_params:
        
# #         print(type(i))

#         string_unformatted = tst_str % replace_params
    
#         print(string_unformatted)
    
    
#         pf= open("param_file_unformatted.txt", "w")

#         pf.write(string_unformatted)
    
    
#     #print(replace_params)
    
    
    
         
# #     pf= open("param_file_unformatted.txt", "w")
        
# #     pf.write(tst_str % replace_params)

# %%
commas = 0

#index = 0

for index, value in enumerate(nw_st):
    
    #index+=1
    
    if value == ',':
        
        commas+=1
        
        #if commas == len(positions_list):
        if commas == len(positions_list):
        
            print(index)

             
            nw_st = nw_st[:index] + '\n' + nw_st[index:]
            
            commas = 0
        
        #if ount%len(positions_list)==0:
        #if commas%5==0:
        
            
#             print(commas)
            
#             nw_st = nw_st[:index] + '\n' + nw_st[index:]




# for i in nw_st:
    
#     if i == ',':
        
#         commas+=1
        
#         if commas ==len(positions_list):
            
#             nw_str = (nw_st[:index] + '\n' + nw_st[index:])
           
#             commas = 0
# Out:
# 98
# 202
# 304
# 405
# 508
# 608
# 710
# 810
# 911

# %%
print(nw_st)
# Out:
# 0.426392395832758, 0.9103636065857955, -1.2949352952923796, 1.2570805772020746, 3.1785480935541024
# ,
#  0.47167853199636256, 0.8191504519999148, -0.9372311832492476, 3.7477206620474224, 1.4328400491294657
#
# , 0.12400941750136327, 0.6251591327383723, 1.2514334727147847, 3.1815841094358968, 0.482755140924199
#
# 3, 0.3223433839816943, 0.7065701320697265, 0.20929427762986275, 2.0688161038016584, 2.5374525117109
#
# 81, 0.29213876066600236, 0.6712646385048495, -0.7711693672197689, 3.3210750775399283, 2.0678240496456
#
# 763, 0.22340852154358692, 0.8404117986514773, 1.1129435366260738, 2.332794126201172, 2.34139828510
#
# 2133, 0.34286657142782745, 0.971440979362093, -0.08364030257072971, 1.4257278065020418, 3.3153493372
#
# 66281, 0.170737722708119, 0.7235432015361439, -1.759252180815515, 0.9126755026609172, 0.9176277571
#
# 185345, 0.20621460514465184, 0.9245075761526478, 0.419168323308401, 2.5200182306691583, 1.279622145
#
# ...

# %%
for index,value in enumerate(nw_st):
    
    if value == ',':
        
        print(index)
# Out:
# 17
# 37
# 58
# 78
# 98
# 121
# 141
# 162
# 182
# 204
# 225
# 245
# 265
# 285
# 307
# 327
# 347
# 368
# 388
# 409
# 430
# 450
# 471
# 491
# 513
# 534
# 554
# 574
# 593
# 614
# 635
# 654
# 676
# 696
# 717
# 736
# 756
# 776
# 796
# 818
# 839
# 859
# 878
# 898
# 920
# 940
# 960
# 979
# 999

# %%
nw_st.count('\n')

# %%
u_s = open("save_unformatted_string.txt", 'x')

# %%
def string_replace():
    
    #track = 0


    for line in nw_st.rsplit('\n'):

        #track+=1

        replace_ps = ''

        replace_ps+=line


        #if track ==1:
            
            #break
        
        replace_ps = replace_ps.rsplit(', ')

        replace_ps = tuple(replace_ps)   
            
        u_s = open("save_unformatted_string.txt", 'w')
        
        print(len(replace_ps))
        
        print(tst_str.count('%s'))
        
        print(tst_str)
            
        testing = tst_str % replace_ps  
        
        u_s.write(testing)
        
        #print(replace_ps)
        
        #print(tst_str)
            
        u_s.close()
        
        replace_ps = str(replace_ps)
        
        for lett in replace_ps:
            
            replace_ps.replace(lett, "")
        
        
    #print(replace_ps)
        
            
            
            #somehow empty replace_ps after each loop

# %%
string_replace()

# %%
# practice_string = """
# ants
# grass
# pie
# loofa
# creamery
# cows
# grass
# amplitude
# lorax
# drseuss
# lorax
# barn
# owl
# window
# juniper 
# owl
# """

# %%
practice_string ="""ants
grass
pie
grass
loofa
creamery
cows
amplitude
lorax
drseuss
barn
owl
window
juniper"""

# %%
#indexes_repl = [3, 6, 10]

indexes_repl = [3, 6, 0]

# %%
test_list = []

for i in practice_string.rsplit("\n"):
    
    test_list.append(str(i))
    
    
for index, value in enumerate(test_list):
    
    print(index)

    if  index in indexes_repl:
        print('true')
        
        test_list[index] = '%s'
        
            #practice_string = practice_string.replace((practice_string.rsplit("\n"))[counter], "00000", 1)
# Out:
# 0
# true
# 1
# 2
# 3
# true
# 4
# 5
# 6
# true
# 7
# 8
# 9
# 10
# 11
# 12
# 13

# %%
#expecting to replace grass, lorax, cows, loofa

print(test_list)
# Out:
# ['%s', 'grass', 'pie', '%s', 'loofa', 'creamery', '%s', 'amplitude', 'lorax', 'drseuss', 'barn', 'owl', 'window', 'juniper']

# %%
s = ''

for word in test_list:
    
    s+= word
    
    s+= ', '
    
print(s)
# Out:
# %s, grass, pie, %s, loofa, creamery, %s, amplitude, lorax, drseuss, barn, owl, window, juniper,

# %%
(practice_string.rsplit("\n"))[2]
# Out:
# 'pie'

# %%
# Out:
# ['%s', 'grass', 'pie', '%s', 'loofa', 'creamery', '%s', 'amplitude', 'lorax', 'drseuss', 'barn', 'owl', 'window', 'juniper']
