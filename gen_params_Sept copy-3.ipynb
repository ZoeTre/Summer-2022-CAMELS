# %%
tst_str =  """#main free parameters
#chi_gas
1.7 
#sigma_crit
6.0
#tau_star_0
1.0
#recipe for quiescent star formation 0=kenn density 1=bigiel1 2=bigiel2
2
#H2 recipe (0 = GK 1 = KMT 2= BR)
0
#ionized gas
#sigma_HII 
0.4 
#fion_internal
0.2
#epsilon_SN_0 
1.7 
#alpha_rh 
3.0 
#f_eject_thresh (km/s)
110.0
#gas is ejected if V_halo<f_eject_thresh
#drive_AGN_winds 
1 
#epsilon_wind_QSO
0.50000
#YIELD 
1.2 
#f_enrich_cold
1.0
#cooling enrichment (0=self-consistent 1=fixed) 
0
#Zh_fixed
0.0
#radio heating parameters: f_Edd_radio
0.002
#f_recycle (recycled gas from mass loss/SN)
0.43
#BH parameters
0.5
#fbhcrit 
0.4
#tau_Q 
0.04 
#mseedbh
1.0E04
#bhmassbulgemassev
1
#0=NOEV 1= ZEV 2=FGAS 3=BHFP
#sigmaBH_create
0.3
#tidal stripping (0/1)
1
#if on, expects arguments:
#f_strip 
1.0
#tau_strip 
0.22
#f_dis
0.8
#to make stripping MORE effective make f_strip<1
#to make stripping less effective make f_strip>1
#f_scatter
0.2
#f_return (re-infall of ejected gas)
0.1
#SQUELCH 
1
#z1 
9.0
#z2 
3.5
#z_squelch
8.0
#z1 and z2 should be regarded as just parameters in the okamoto fitting fnc
#z_squelch is the redshift that squelching is turned on
#disk model 0=SP 1=isothermal 2=MMW
2
#alpha_burst
3.0
#disk instability
1
#0=off 1=on (stars+gas)
#epsilon_m
0.3
#cosmological parameters
#geometry: 0=EDS, 1=FLAT, 2=OPEN
1
#Omega_0 (matter) 
0.25100
#Omega_Lambda_0 
0.74900
#h_100
0.6711
#f_baryon: negative number means use default value
0.1952
#variance file
#"variance/var.planck15.dat"
#save_history
0
#metallicity binning information
#NMET_SFHIST
12
#minmet_sfhist
-2.5
#maxmet_sfhist
0.6
#NT_SFHIST
1381
#dt_sfhist
0.01
#zmin_outputsfhist
0.79000
#zmax_outputsfhist
1.80000
#mstarmin_outputsfhist
10.0
#minimum root mass (Msun)
2.65751E10
#tree file format 0=bolshoi planck 1=illustrisTNG
1
#output
#NSNAP (number of snapshots in the merger tree file)
100
#NZOUT
1
#minsnap maxsnap must be NZOUT entries (set to 1 NSNAP for NZOUT=1)
0 99
#quantities to output:
#galprop
1
#halos
1
#history
0
#trace
0
#mergers
0
#GAL_SELECT 0=mstar 1=mhalo
1
2.65751E10
#C_rad (major):
#sp-sp
2.5
#sp-e
0
#e-e
0
#C_rad (minor):
#sp-sp
1.35
#sp-e
0
#e-e
0
#C_int (major):
#sp-sp
0.5
#sp-e
0.5
#e-e
0.5
#C_int (minor):
#sp-sp
0.5
#sp-e
0.5
#e-e
0.5
#usemainbranchonly (0/1)
0"""

# %%
import sys

import os

SIM = str(sys.argv[1])
nsubvol = int(sys.argv[2])
m_th = str(sys.argv[3])
partition = int(sys.argv[4])
lib_path = '%s' % str(sys.argv[5])
in_path = '%s' % str(sys.argv[6])
out_path = '%s' % str(sys.argv[7])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [59], in <module>
#       3 import os
#       5 SIM = str(sys.argv[1])
# ----> 6 nsubvol = int(sys.argv[2])
#       7 m_th = str(sys.argv[3])
#       8 partition = int(sys.argv[4])
#
# ValueError: invalid literal for int() with base 10: '/dev/shm/2061919/kernel-c3357696-b9d2-4b46-b29c-fea61296edb6.json'

# %%
# in_path = "fake in path"
# out_path = "fake out path"
# lib_path = "fake lib path"

# %%
top_str = """#gf parameter file (gfn.v2)\n\
#december 2017\n\
#pathname of input and output\n\
"%s/%s/"\n\
#pathname of library files\n\
"%s/"\n\
#verbosity\n\
1\n\
#seed\n\
-12345\n"""

# %%
top_str = top_str % (in_path, out_path, lib_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [62], in <module>
# ----> 1 top_str = top_str % (in_path, out_path, lib_path)
#
# NameError: name 'in_path' is not defined

# %%
params = [
    
"chi_gas",

"sigma_crit",

"tau_star_0",

"quiescent star formation",

"H2 recipe",

"sigma_HII",

"fion_internal",

"epsilon_SN_0",

"alpha_rh",

"f_eject_thresh",

"drive_AGN_winds",

"epsilon_wind_QSO",

"YIELD",

"f_enrich_cold",

"cooling enrichment",

"Zh_fixed",

"f_Edd_radio",

"f_recycle",

"BH parameters",

"fbhcrit",

"tau_Q",

"mseedbh",

"bhmassbulgemassev",

"sigmaBH_create",

"tidal stripping",

"f_strip",

"tau_strip",

"f_dis",

"f_scatter",

"f_return",

"SQUELCH",

"z1",

"z2",

"z_squelch",


"disk model",

"alpha_burst",

"disk instability",

"epsilon_m",

"geometry",

"Omega_0",

"Omega_Lambda_0",

"h_100",

"f_baryon"
 

    ]

# %%
txt_to_read = open('/mnt/home/ztremitiere/extreme_values.txt', 'r')

# %%
first_line = (txt_to_read.readline())

# %%
chosen_params = [str(i) for i in first_line.rsplit(", ") if i!= ' \n']

# %%
#params_fake = ['epsilon_m', 'f_scatter', 'tau_Q', 'alpha_rh', "alpha_burst"]

# %%
positions_list = []

for position, para in enumerate(params):
    
    for p in chosen_params:
    
        if para == p:
            
            print(position)
            
            positions_list.append(position)
# Out:
# 0
# 1
# 5
# 6
# 7
# 8
# 11
# 12
# 27
# 28

# %%
txt_to_read = open('/mnt/home/ztremitiere/extreme_values.txt', 'r')

st =''


for line in txt_to_read:
    
    st += line

# %%
print(st)
# Out:
# chi_gas, sigma_crit, sigma_HII, fion_internal, epsilon_SN_0, alpha_rh, f_eject_thrush, epsilon_wind_QSO, YIELD, f_dis, f_scatter, f_return,
# 6.8, 6, 0.4, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,
# 0.425, 6, 0.4, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,
# 1.7, 60, 0.4, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,
# 1.7, 0.6, 0.4, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,
# 1.7, 6, 1.6, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,
# 1.7, 6, 0.1, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,
# 1.7, 6, 0.4, 0.8, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,
# 1.7, 6, 0.4, 0.05, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,
# 1.7, 6, 0.4, 0.2, 6.8, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,
# 1.7, 6, 0.4, 0.2, 0.425, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,
# 1.7, 6, 0.4, 0.2, 1.7, 5, 110, 0.5, 1.2, 0.8, 0.2, 0.1,
# 1.7, 6, 0.4, 0.2, 1.7, 1, 110, 0.5, 1.2, 0.8, 0.2, 0.1,
# 1.7, 6, 0.4, 0.2, 1.7, 3, 440, 0.5, 1.2, 0.8, 0.2, 0.1,
# 1.7, 6, 0.4, 0.2, 1.7, 3, 27.5, 0.5, 1.2, 0.8, 0.2, 0.1,
# ...

# %%
nw_st = ""
count=1
for line in st.rsplit("\n"):
    
    one_line = (st.rsplit("\n")[count])
    count+=1
    nw_st += one_line
    
    
#     for i in range(1, 5):

#         one_line = (st.rsplit("\n")[i])
    
#         nw_st += one_line
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [71], in <module>
#       2 count=1
#       3 for line in st.rsplit("\n"):
# ----> 5     one_line = (st.rsplit("\n")[count])
#       6     count+=1
#       7     nw_st += one_line
#
# IndexError: list index out of range

# %%
print(nw_st)
# Out:
# 6.8, 6, 0.4, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,0.425, 6, 0.4, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 60, 0.4, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 0.6, 0.4, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 1.6, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.1, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.8, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.05, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 6.8, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 0.425, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 5, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 1, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 3, 440, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 3, 27.5, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 3, 110, 1, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 3, 110, 0.25, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 3, 110, 0.5, 2.4, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 3, 110, 0.5, 0.6, 0.8, 0.2, 0.1,
# ...

# %%
#nw_st

# %%
range_params = len(positions_list) + 1

# %%
print(range_params)
# Out:
# 11

# %%
def give_parameters(LineNumber):
    
    sorted_parameters = []

    parameter_set = ''

    for num in nw_st.rsplit(', '):
    
        parameter_set += (num + ', ')
    
        if len(parameter_set.rsplit(', ')) == range_params:
        
            sorted_parameters.append(parameter_set)
        
            parameter_set = ''
            
    return (sorted_parameters[LineNumber])

# %%
def text_file_name(num):
    

    name = 'params_formatted' + '_' + str(num)
        
    return str(name)

# %%
def format_newvalsstring():
    
    pf.write('#main free parameters\n')
    pf.write("#chi_gas sigma_crit\n")
    pf.write(new_vals_string.rsplit(', ')[0])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[1])
    pf.write('\n')
    
    pf.write('#tau_star_0')
    pf.write('\n')
    pf.write(new_vals_string.rsplit(', ')[2])
    pf.write('\n')
    
    pf.write('#recipe for quiescent star formation 0=kenn density 1=bigiel1 2=bigiel2\n')
    pf.write(new_vals_string.rsplit(', ')[3])
    pf.write('\n')
    
    
    pf.write('#H2 recipe (0 = GK 1 = KMT 2= BR)\n')
    pf.write(new_vals_string.rsplit(', ')[4])
    pf.write('\n')
    
    pf.write('#ionized gas\n') 
    
    pf.write('#sigma_HII fion_internal\n')
    pf.write(new_vals_string.rsplit(', ')[5])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[6])
    pf.write('\n')
    
    pf.write("#epsilon_SN_0 alpha_rh f_eject_thresh (km/s)\n") 
    pf.write("#gas is ejected if V_halo<f_eject_thresh\n")
    pf.write(new_vals_string.rsplit(', ')[7])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[8])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[9])
    pf.write('\n')
    
    pf.write('#drive_AGN_winds epsilon_wind_QSO\n')         
    pf.write(new_vals_string.rsplit(', ')[10])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[11])
    pf.write('\n') 
    
    pf.write('#YIELD f_enrich_cold\n')
    pf.write(new_vals_string.rsplit(', ')[12])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[13])
    pf.write('\n') 
    
    pf.write('#cooling enrichment (0=self-consistent 1=fixed) Zh_fixed\n')
    pf.write(new_vals_string.rsplit(', ')[14])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[15])
    pf.write('\n')
    
    pf.write('#radio heating parameters: f_Edd_radio\n')         
    pf.write(new_vals_string.rsplit(', ')[16])
    pf.write('\n')
    
    pf.write('#f_recycle (recycled gas from mass loss/SN)\n')
    pf.write(new_vals_string.rsplit(', ')[17])
    pf.write('\n')
    
    pf.write('#BH parameters\n')
    pf.write('#fbhcrit tau_Q mseedbh\n')
    pf.write(new_vals_string.rsplit(', ')[18])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[19])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[20])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[21])
    pf.write('\n')
    
    pf.write('#bhmassbulgemassev\n')
    pf.write('#0=NOEV 1= ZEV 2=FGAS 3=BHFP\n')
    pf.write(new_vals_string.rsplit(', ')[22])
    pf.write('\n')
    
    pf.write('#sigmaBH_create\n')
    pf.write(new_vals_string.rsplit(', ')[23])
    pf.write('\n')
    
    pf.write('#tidal stripping (0/1)\n')
    pf.write('#if on, expects arguments f_strip tau_strip f_dis\n')
    pf.write('#to make stripping MORE effective make f_strip<1\n')
    pf.write('#to make stripping less effective make f_strip>1\n')
    pf.write(new_vals_string.rsplit(', ')[24])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[25])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[26])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[27])
    pf.write('\n')
    
    pf.write('#f_scatter\n')
    pf.write(new_vals_string.rsplit(', ')[28])
    pf.write('\n')
    
    pf.write('#f_return (re-infall of ejected gas)\n')
    pf.write(new_vals_string.rsplit(', ')[29])
    pf.write('\n')
    
    pf.write('#SQUELCH z1 z1 z_squelch\n')
    pf.write('#z1 and z2 should be regarded as just parameters in the okamoto fitting fnc') 
    pf.write('\n') 
    pf.write('#z_squelch is the redshift that squelching is turned on')
    pf.write('\n')
    pf.write(new_vals_string.rsplit(', ')[30])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[31])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[32])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[33])
    pf.write('\n')
    
    pf.write('#disk model 0=SP 1=isothermal 2=MMW\n')
    pf.write(new_vals_string.rsplit(', ')[34])
    pf.write('\n')
    
    pf.write('#alpha_burst\n')
    pf.write(new_vals_string.rsplit(', ')[35])
    pf.write('\n')
    
    pf.write('#disk instability\n')
    pf.write('#0=off 1=on (stars+gas)\n')
    pf.write('#epsilon_m\n')
    pf.write(new_vals_string.rsplit(', ')[36])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[37])
    pf.write('\n')
    
    pf.write('#cosmological parameters\n')
    pf.write('#geometry: 0=EDS, 1=FLAT, 2=OPEN\n')
    pf.write(new_vals_string.rsplit(', ')[39])
    pf.write('\n')
    
    pf.write('#Omega_0 (matter) Omega_Lambda_0 h_100\n')
    pf.write(new_vals_string.rsplit(', ')[40])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[41])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[42])
    pf.write('\n')
    
    pf.write('#f_baryon: negative number means use default value\n')
    pf.write(new_vals_string.rsplit(', ')[43])
    pf.write('\n')
    
    pf.write('#variance file\n\"variance/var.planck15.dat"\n')
    pf.write('#save_history\n')
    pf.write('1')
             
    pf.write('#metallicity binning information\n')
    pf.write('#NMET_SFHIST minmet_sfhist maxmet_sfhist\n')
    pf.write(new_vals_string.rsplit(', ')[44])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[45])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[46])
    pf.write('\n')
    
    pf.write('#NT_SFHIST dt_sfhist\n')
    pf.write(new_vals_string.rsplit(', ')[47])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[48])
    pf.write('\n')
    
    pf.write('#zmin_outputsfhist zmax_outputsfhist mstarmin_outputsfhist [code units]\n')
    pf.write(new_vals_string.rsplit(', ')[49])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[50])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[51])
    pf.write('\n')
    
    pf.write("#minimum root mass (Msun)\n")
    pf.write(new_vals_string.rsplit(', ')[52])
    pf.write('\n')
   
    pf.write('#tree file format 0=bolshoi planck 1=illustrisTNG\n')
    pf.write(new_vals_string.rsplit(', ')[53])
    pf.write('\n')
    
    pf.write('#filename of file containing list of tree filenames\n')
    pf.write(new_vals_string.rsplit(', ')[54])
    pf.write('\n')
    
    #here should be path 
    
    pf.write('#output\n')
    pf.write('#NSNAP (number of snapshots in the merger tree file)\n')
    pf.write(new_vals_string.rsplit(', ')[55])
    pf.write('\n')
             
    pf.write('#NZOUT\n')
    pf.write('1')
    
    pf.write('#minsnap maxsnap must be NZOUT entries (set to 1 NSNAP for NZOUT=1)\n')
    pf.write(new_vals_string.rsplit(', ')[56])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[57])
    pf.write('\n')
    
    pf.write('#quantities to output:\n')
    pf.write('#galprop halos history trace mergers\n')
    pf.write(new_vals_string.rsplit(', ')[58])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[59])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[60])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[61])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[62])
    pf.write('\n')
   
    pf.write('#GAL_SELECT 0=mstar 1=mhalo\n')
    pf.write(new_vals_string.rsplit(', ')[63])
    pf.write('\n')
    
    pf.write(new_vals_string.rsplit(', ')[64])
    pf.write('\n')
    
    pf.write('#C_rad (major): sp-sp, sp-e, e-e\n')
    pf.write(new_vals_string.rsplit(', ')[65])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[66])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[67])
    pf.write('\n')
    
    pf.write('#C_rad (minor): sp-sp, sp-e, e-e\n')
    pf.write(new_vals_string.rsplit(', ')[68])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[69])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[70])
    pf.write('\n')
    
    pf.write('#C_int (major): sp-sp, sp-e, e-e\n')
    pf.write(new_vals_string.rsplit(', ')[71])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[72])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[73])
    pf.write('\n')
    
    pf.write('#C_int (minor): sp-sp, sp-e, e-e\n')
    pf.write(new_vals_string.rsplit(', ')[74])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[75])
    pf.write(' ')
    pf.write(new_vals_string.rsplit(', ')[76])
    pf.write('\n')
    
    pf.write('#usemainbranchonly (0/1)\n')
    #pf.write(new_vals_string.rsplit(', ')[77])
    
    pf.close()

# %%
# list_of_fiducial_values = []

# for j in tst_str.rsplit("\n"):

#         if j.startswith('#'):

#             pass

#         else:

#             list_of_fiducial_values.append(str(j))

# %%
# lines_infile = int(len(nw_st.rsplit(', '))/(len(positions_list)))

# %%
print(nw_st)
# Out:
# 6.8, 6, 0.4, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,0.425, 6, 0.4, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 60, 0.4, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 0.6, 0.4, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 1.6, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.1, 0.2, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.8, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.05, 1.7, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 6.8, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 0.425, 3, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 5, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 1, 110, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 3, 440, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 3, 27.5, 0.5, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 3, 110, 1, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 3, 110, 0.25, 1.2, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 3, 110, 0.5, 2.4, 0.8, 0.2, 0.1,1.7, 6, 0.4, 0.2, 1.7, 3, 110, 0.5, 0.6, 0.8, 0.2, 0.1,
# ...

# %%
list_of_fiducial_values = []

for element in tst_str.rsplit("\n"):

        if element.startswith('#'):

            pass

        else:

            list_of_fiducial_values.append(str(element))

# %%
print(list_of_fiducial_values)
# Out:
# ['1.7 ', '6.0', '1.0', '2', '0', '0.4 ', '0.2', '1.7 ', '3.0 ', '110.0', '1 ', '0.50000', '1.2 ', '1.0', '0', '0.0', '0.002', '0.43', '0.5', '0.4', '0.04 ', '1.0E04', '1', '0.3', '1', '1.0', '0.22', '0.8', '0.2', '0.1', '1', '9.0', '3.5', '8.0', '2', '3.0', '1', '0.3', '1', '0.25100', '0.74900', '0.6711', '0.1952', '0', '12', '-2.5', '0.6', '1381', '0.01', '0.79000', '1.80000', '10.0', '2.65751E10', '1', '100', '1', '0 99', '1', '1', '0', '0', '0', '1', '2.65751E10', '2.5', '0', '0', '1.35', '0', '0', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0']

# %%
lines_infile = int(len(nw_st.rsplit(', '))/(len(positions_list)))

# %%
for i in range(0, lines_infile):

    #remember give_parameters gives each parameter set. So x_st is equal to each parameter set one by one/iteratively
    x_st = give_parameters(i) #this gets updated for each line

    x_stl = x_st.rsplit(', ')


    for index, value in enumerate(list_of_fiducial_values):  

        if index in positions_list:

            list_of_fiducial_values[index] = x_stl[0]

            x_stl.pop(0)


    new_vals_string = ''

    for val in list_of_fiducial_values:

        new_vals_string+= val

        new_vals_string+= ', '

    new_vals_string = new_vals_string[:-2]

    print(new_vals_string)
# Out:
# 6.8, 6, 1.0, 2, 0, 0.4, 0.2, 1.7, 3, 110.0, 1 , 110, 0.5, 1.0, 0, 0.0, 0.002, 0.43, 0.5, 0.4, 0.04 , 1.0E04, 1, 0.3, 1, 1.0, 0.22, 1.2, 0.8, 0.1, 1, 9.0, 3.5, 8.0, 2, 3.0, 1, 0.3, 1, 0.25100, 0.74900, 0.6711, 0.1952, 0, 12, -2.5, 0.6, 1381, 0.01, 0.79000, 1.80000, 10.0, 2.65751E10, 1, 100, 1, 0 99, 1, 1, 0, 0, 0, 1, 2.65751E10, 2.5, 0, 0, 1.35, 0, 0, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0
# 0.2, 0.1,0.425, 1.0, 2, 0, 6, 0.4, 0.2, 1.7, 110.0, 1 , 3, 110, 1.0, 0, 0.0, 0.002, 0.43, 0.5, 0.4, 0.04 , 1.0E04, 1, 0.3, 1, 1.0, 0.22, 0.5, 1.2, 0.1, 1, 9.0, 3.5, 8.0, 2, 3.0, 1, 0.3, 1, 0.25100, 0.74900, 0.6711, 0.1952, 0, 12, -2.5, 0.6, 1381, 0.01, 0.79000, 1.80000, 10.0, 2.65751E10, 1, 100, 1, 0 99, 1, 1, 0, 0, 0, 1, 2.65751E10, 2.5, 0, 0, 1.35, 0, 0, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0
# ...

# %%
#generate files.list for each partition folder that contains the isotree path 

#inside every partition folder (so every params_formatted_i__h_j_k  /mnt/home/ztremitiere/ceph/ICsSAM/cLH537/params_dump/sc-sam_i/h_j_k there's 

for folder in range(0,5):
#this used to be range 0, nsubvol but i changed it as a test
    for h in range(0, 2):
        for j in range(0, 2):
            for k in range(0, 2):
                
                content = str(1) + "\n" + '"/mnt/ceph/users/lperez/ICsSAM/cLH537/output/isotrees/isotree_%s_%s_%s.dat"' % (h, j, k)
                
        
                os.chdir("/mnt/home/ztremitiere/ceph/ICsSAM/cLH537/params_dump/sc-sam_%s/%s_%s_%s" % (folder, h, j, k))
                
                file = open('files.list', 'x') 

                file = open('files.list', 'w')
                
                file.write(content)

# %%
# content = str(1) + "\n" + '"/mnt/ceph/users/lperez/ICsSAM/cLH537/output/isotrees/isotree_1_1_1.dat"'

# print(content)
# Out:
# 1
# "/mnt/ceph/users/lperez/ICsSAM/cLH537/output/isotrees/isotree_1_1_1.dat"

# %%
for folder in range(0,5):
#this used to be range 0, nsubvol but i changed it as a test
    for h in range(0, 2):
        for j in range(0, 2):
            for k in range(0, 2):
           
                tree_filenames = "/mnt/home/ztremitiere/ceph/ICsSAM/cLH537/params_dump/sc-sam_%s/%s_%s_%s/files.list" % (folder, h, j, k)
                    
                print("sc-sam_%s/%s_%s_%s" % (folder, h, j, k))
                
                print("%s_%s_%s" % (h,j,k))

                os.chdir("/mnt/home/ztremitiere/ceph/ICsSAM/cLH537/params_dump/sc-sam_%s/%s_%s_%s" % (folder, h, j, k)) 
                #os.chdir("/mnt/home/ztremitiere/ceph/ICsSAM/cLH537/params_dump/sc-sam")
                    

                subvol = "%s_%s_%s" % (h,j,k) #subvol gets passed as one of the conditions for function text_file_name
                    
                pf = open(text_file_name(folder), 'x') 

                pf = open(text_file_name(folder), 'w')

                pf.write(top_str)

                    
                format_newvalsstring()
# Out:
# sc-sam_0/0_0_0
# 0_0_0
# sc-sam_0/0_0_1
# 0_0_1
# sc-sam_0/0_1_0
# 0_1_0
# sc-sam_0/0_1_1
# 0_1_1
# sc-sam_0/1_0_0
# 1_0_0
# sc-sam_0/1_0_1
# 1_0_1
# sc-sam_0/1_1_0
# 1_1_0
# sc-sam_0/1_1_1
# 1_1_1
# sc-sam_1/0_0_0
# 0_0_0
# sc-sam_1/0_0_1
# 0_0_1
# sc-sam_1/0_1_0
# 0_1_0
# sc-sam_1/0_1_1
# 0_1_1
# sc-sam_1/1_0_0
# 1_0_0
# sc-sam_1/1_0_1
# 1_0_1
# sc-sam_1/1_1_0
# 1_1_0
# sc-sam_1/1_1_1
# 1_1_1
# sc-sam_2/0_0_0
# 0_0_0
# sc-sam_2/0_0_1
# 0_0_1
# sc-sam_2/0_1_0
# 0_1_0
# sc-sam_2/0_1_1
# 0_1_1
# sc-sam_2/1_0_0
# 1_0_0
# sc-sam_2/1_0_1
# 1_0_1
# sc-sam_2/1_1_0
# 1_1_0
# sc-sam_2/1_1_1
# 1_1_1
# sc-sam_3/0_0_0
# 0_0_0
# sc-sam_3/0_0_1
# 0_0_1
# sc-sam_3/0_1_0
# 0_1_0
# sc-sam_3/0_1_1
# 0_1_1
# sc-sam_3/1_0_0
# 1_0_0
# sc-sam_3/1_0_1
# 1_0_1
# sc-sam_3/1_1_0
# 1_1_0
# sc-sam_3/1_1_1
# 1_1_1
# sc-sam_4/0_0_0
# 0_0_0
# sc-sam_4/0_0_1
# 0_0_1
# sc-sam_4/0_1_0
# 0_1_0
# sc-sam_4/0_1_1
# 0_1_1
# sc-sam_4/1_0_0
# 1_0_0
# sc-sam_4/1_0_1
# 1_0_1
# sc-sam_4/1_1_0
# 1_1_0
# sc-sam_4/1_1_1
# 1_1_1

# %%
#copy params_formatted files and give them name SAM recognizes. So inside every ?_?_? folder there should be: files.list , params_formatted_? , param_varyparams.scsam

# i think param_varyparams.scsam is what they're supposed to be called
import shutil 

for folder in range(0,5):
#this used to be range 0, nsubvol but i changed it as a test
    for h in range(0, 2):
        for j in range(0, 2):
            for k in range(0, 2):
                
                os.chdir("/mnt/home/ztremitiere/ceph/ICsSAM/cLH537/params_dump/sc-sam_%s/%s_%s_%s" % (folder, h, j, k))
                
                orig_name = 'params_formatted_%s' % (folder)
                
                copy_name = 'param_varyparams.scsam'
                
                shutil.copy(orig_name, copy_name)

# %%
#can i run this notebook without the sbatch

#like now that i have my folders, i don't need the sbatch right now

#can i do that one major step of getting all my files to the correct places

#from there i would do the step of writing out in english how my sbatch set up needs to change

# %%
print('hi')
